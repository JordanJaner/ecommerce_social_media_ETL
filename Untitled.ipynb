# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Store CSV to DF

# %%
csv_file = "Resources/all_platforms.csv"
all_platforms_df = pd.read_csv(csv_file)
all_platforms_df.head()
# Out:
#       Date  Facebook  Pinterest  StumbleUpon  Twitter  reddit  Tumblr  \
# 0  2009-04     12.89        0.0        42.45     6.69    9.83     0.0
# 1  2009-05     15.88        0.0        42.55    10.45    9.10     0.0
# 2  2009-06     17.02        0.0        38.08    11.25   14.80     0.0
# 3  2009-07     19.08        0.0        43.41    10.55   11.64     0.0
# 4  2009-08     24.45        0.0        38.84    11.37   11.85     0.0
#
#    YouTube  Instagram  LinkedIn  Digg  MySpace  Fark  Google+  NowPublic  \
# 0      0.0        0.0      0.00  6.02    19.04  0.30      0.0       0.03
# 1      0.0        0.0      0.27  6.85    11.06  0.65      0.0       0.04
# 2      0.0        0.0      0.50  5.17     9.46  1.03      0.0       0.05
# 3      0.0        0.0      0.40  5.05     6.86  0.34      0.0       0.05
# 4      0.0        0.0      0.45  3.92     5.85  0.64      0.0       0.08
#
#    news.ycombinator.com  Delicious  VKontakte  Vimeo  Other
# ...

# %%
csv_file_2 = "Resources/console.csv"
console_df = pd.read_csv(csv_file_2)
console_df.head()
# Out:
#       Date  Facebook  reddit  Tumblr  YouTube  Twitter  Pinterest  \
# 0  2012-08     79.24    1.93     0.0    12.37     1.65       0.98
# 1  2012-09     75.34    3.15     0.0    13.23     2.31       1.22
# 2  2012-10     57.16    3.18     0.0    26.70     6.23       1.43
# 3  2012-11     57.54    3.59     0.0    32.05     1.48       1.05
# 4  2012-12     56.82    4.51     0.0    31.12     2.62       2.03
#
#    StumbleUpon  Instagram  Google+  VKontakte  NowPublic  Fark  Vimeo  \
# 0         1.74        0.0      0.0        0.0       1.10  0.02   0.82
# 1         2.97        0.0      0.0        0.0       1.10  0.05   0.45
# 2         2.92        0.0      0.0        0.0       1.42  0.07   0.68
# 3         1.96        0.0      0.0        0.0       0.72  0.14   1.09
# 4         1.88        0.0      0.0        0.0       0.60  0.10   0.12
#
#    LinkedIn  Other
# 0      0.01   0.12
# 1      0.01   0.17
# 2      0.02   0.18
# 3      0.03   0.36
# 4      0.02   0.17

# %%
csv_file_3 = "Resources/Desktop_201001-202112.csv"
desktop_df = pd.read_csv(csv_file_3)
desktop_df.head()
# Out:
#       Date  Facebook  StumbleUpon  Pinterest  Twitter  reddit  Tumblr  \
# 0  2010-01     48.03        30.33        0.0     5.86    5.75     0.0
# 1  2010-02     40.42        33.79        0.0     7.59    5.27     0.0
# 2  2010-03     30.79        41.43        0.0     8.59    6.31     0.0
# 3  2010-04     34.86        38.20        0.0     7.30    5.49     0.0
# 4  2010-05     39.24        35.63        0.0     6.75    5.92     0.0
#
#    YouTube  Digg  LinkedIn  ...  MySpace  Google+  NowPublic  Instagram  \
# 0     4.83  2.90      0.25  ...     0.60      0.0       0.08        0.0
# 1     5.05  3.30      0.31  ...     1.18      0.0       1.55        0.0
# 2     4.43  2.14      0.35  ...     2.91      0.0       1.41        0.0
# 3     3.15  2.05      0.29  ...     6.20      0.0       0.97        0.0
# 4     3.48  1.86      0.26  ...     4.61      0.0       0.88        0.0
#
#    news.ycombinator.com  Delicious  VKontakte  Vimeo  orkut  Other
# ...

# %%
csv_file_4 = "Resources/mobile_social_media.csv"
mobile_df = pd.read_csv(csv_file_4)
mobile_df.head()
# Out:
#       Date  Facebook  Pinterest  Twitter  Instagram  StumbleUpon  YouTube  \
# 0  2009-04     18.27        0.0    23.64        0.0         0.94      0.0
# 1  2009-05     19.29        0.0    37.61        0.0         1.95      0.0
# 2  2009-06     19.32        0.0    35.45        0.0         0.97      0.0
# 3  2009-07     24.80        0.0    31.96        0.0         1.69      0.0
# 4  2009-08     31.70        0.0    28.85        0.0         0.88      0.0
#
#    reddit  Tumblr  LinkedIn  Google+  Fark   Digg  NowPublic  \
# 0   20.60     0.0      0.00      0.0  0.86  15.51       0.06
# 1   15.07     0.0      0.48      0.0  1.58  12.56       0.08
# 2   21.03     0.0      0.61      0.0  2.21  13.37       0.10
# 3   15.90     0.0      0.58      0.0  0.87  16.26       0.12
# 4   21.50     0.0      0.61      0.0  1.19   9.63       0.17
#
#    news.ycombinator.com  Other
# 0                  0.58  19.53
# 1                  1.00  10.38
# 2                  0.58   6.36
# ...

# %%
csv_file_5 = "Resources/US_tablet_data.csv"
tablet_df = pd.read_csv(csv_file_5)
tablet_df.head()
# Out:
#                                                                                                           US_tablet
# Date    Facebook Pinterest Twitter StumbleUpon Tumblr reddit YouTube Instagram Google+ Fark LinkedIn Digg     Other
# 2012-09 21.27    71.46     1.58    2.2         0      2.54   0.44    0         0       0.1  0.15     0.04      0.23
# 2012-10 17.55    73.79     3.24    1.66        0      2.56   0.71    0         0       0.09 0.12     0.04      0.24
# 2012-11 19.26    70.49     2.9     3.9         0      2.26   0.67    0         0       0.12 0.09     0.02      0.27
# 2012-12 21.31    64.42     4.56    6.9         0      1.95   0.46    0         0       0.08 0.11     0.03      0.18

# %%
retail_food_17_file = "Resources/retail_food_17.csv"
retail_food_17_df = pd.read_csv(retail_food_17_file)
retail_food_17_df.head(20)
# Out:
#    Kind of Business Retail and food services sales, total  \
# 0         Jan. 2017                               421,943
# 1         Feb. 2017                               418,315
# 2         Mar. 2017                               483,082
# 3         Apr. 2017                               465,788
# 4            May-17                               494,621
# 5         Jun. 2017                               481,729
# 6         Jul. 2017                               475,374
# 7         Aug. 2017                               490,324
# 8         Sep. 2017                               469,710
# 9         Oct. 2017                               476,014
# 10        Nov. 2017                               497,748
# 11        Dec. 2017                               558,215
#
#    Retail sales and food services excl motor vehicle and parts  \
# 0                                             336,756
# 1                                             328,901
# ...

# %%
rename_retail_food_17 = retail_food_17_df.rename(columns={"Kind of Business":"Date"})
rename_retail_food_17.head()
# Out:
#         Date Retail and food services sales, total  \
# 0  Jan. 2017                               421,943
# 1  Feb. 2017                               418,315
# 2  Mar. 2017                               483,082
# 3  Apr. 2017                               465,788
# 4     May-17                               494,621
#
#   Retail sales and food services excl motor vehicle and parts  \
# 0                                            336,756
# 1                                            328,901
# 2                                            376,796
# 3                                            368,476
# 4                                            388,989
#
#   Retail sales and food services excl gasoline stations  \
# 0                                            386,019
# 1                                            384,105
# 2                                            443,979
# 3                                            426,328
# ...

# %%
reduced_retail_17_df = rename_retail_food_17[["Date", "Retail sales, total", "Electronic shopping and mail order houses", "Electronics and appliance stores", "Clothing stores", "Hobby, toy, and game stores"]]
reduced_retail_17_df.head()
# Out:
#         Date Retail sales, total Electronic shopping and mail order houses  \
# 0  Jan. 2017             368,960                                    41,456
# 1  Feb. 2017             365,480                                    41,662
# 2  Mar. 2017             422,891                                    42,157
# 3  Apr. 2017             407,165                                    42,922
# 4     May-17             434,450                                    43,098
#
#   Electronics and appliance stores Clothing stores Hobby, toy, and game stores
# 0                            7,034          11,843                       1,182
# 1                            6,719          12,703                       1,181
# 2                            7,495          15,785                       1,355
# 3                            6,673          15,683                       1,278
# 4                            7,155          16,005                       1,247

# %%
retail_food_18_file = "Resources/retail_food_18.csv"
retail_food_18_df = pd.read_csv(retail_food_18_file)
retail_food_18_df.head(20)
# Out:
#    Kind of Business Retail and food services sales, total  \
# 0         Jan. 2018                               444,286
# 1         Feb. 2018                               435,373
# 2         Mar. 2018                               508,383
# 3         Apr. 2018                               480,373
# 4          May 2018                               527,991
# 5         Jun. 2018                               507,106
# 6         Jul. 2018                               505,209
# 7         Aug. 2018                               520,544
# 8         Sep. 2018                               477,137
# 9         Oct. 2018                               503,602
# 10        Nov. 2018                               518,457
# 11        Dec. 2018                               556,614
# 12            TOTAL                             5,985,075
#
#    Retail sales and food services excl motor vehicle and parts  \
# 0                                             356,043
# ...

# %%
rename_retail_food_18 = retail_food_18_df.rename(columns={"Kind of Business":"Date"})
rename_retail_food_18.head()
# Out:
#         Date Retail and food services sales, total  \
# 0  Jan. 2018                               444,286
# 1  Feb. 2018                               435,373
# 2  Mar. 2018                               508,383
# 3  Apr. 2018                               480,373
# 4   May 2018                               527,991
#
#   Retail sales and food services excl motor vehicle and parts  \
# 0                                            356,043
# 1                                            345,645
# 2                                            398,623
# 3                                            380,907
# 4                                            418,752
#
#   Retail sales and food services excl gasoline stations  \
# 0                                            405,332
# 1                                            398,494
# 2                                            466,197
# 3                                            437,800
# ...

# %%
reduced_retail_18_df = rename_retail_food_18[["Date", "Retail sales, total", "Electronic shopping and mail order houses", "Electronics and appliance stores", "Clothing stores", "Hobby, toy, and game stores"]]
reduced_retail_18_df.head()
# Out:
#         Date Retail sales, total Electronic shopping and mail order houses  \
# 0  Jan. 2018             389,808                                    46,387
# 1  Feb. 2018             380,671                                    47,272
# 2  Mar. 2018             444,994                                    47,799
# 3  Apr. 2018             420,245                                    48,196
# 4   May 2018             464,050                                    48,140
#
#   Electronics and appliance stores Clothing stores Hobby, toy, and game stores
# 0                            7,290          11,643                       1,187
# 1                            6,972          12,926                       1,230
# 2                            7,581          16,382                       1,720
# 3                            6,835          14,945                       1,358
# 4                            7,397          17,132                       1,438

# %%
retail_food_19_file = "Resources/retail_food_19.csv"
retail_food_19_df = pd.read_csv(retail_food_19_file)
retail_food_19_df.head(20)
# Out:
#    Kind of Business Retail and food services sales, total  \
# 0         Jan. 2019                               456,538
# 1         Feb. 2019                               442,274
# 2         Mar. 2019                               513,845
# 3         Apr. 2019                               506,920
# 4            19-May                               544,203
# 5         Jun. 2019                               515,269
# 6         Jul. 2019                               528,710
# 7         Aug. 2019                               541,951
# 8         Sep. 2019                               493,076
# 9         Oct. 2019                               522,195
# 10        Nov. 2019                               532,130
# 11        Dec. 2019                               587,471
#
#    Retail sales and food services excl motor vehicle and parts  \
# 0                                             368,649
# 1                                             352,651
# ...

# %%
rename_retail_food_19 = retail_food_19_df.rename(columns={"Kind of Business":"Date"})
rename_retail_food_19.head()
# Out:
#         Date Retail and food services sales, total  \
# 0  Jan. 2019                               456,538
# 1  Feb. 2019                               442,274
# 2  Mar. 2019                               513,845
# 3  Apr. 2019                               506,920
# 4     19-May                               544,203
#
#   Retail sales and food services excl motor vehicle and parts  \
# 0                                            368,649
# 1                                            352,651
# 2                                            403,490
# 3                                            403,550
# 4                                            432,418
#
#   Retail sales and food services excl gasoline stations  \
# 0                                            420,099
# 1                                            406,760
# 2                                            471,780
# 3                                            462,650
# ...

# %%
reduced_retail_19_df = rename_retail_food_19[["Date", "Retail sales, total", "Electronic shopping and mail order houses", "Electronics and appliance stores", "Clothing stores", "Hobby, toy, and game stores"]]
reduced_retail_19_df.head()
# Out:
#         Date Retail sales, total Electronic shopping and mail order houses  \
# 0  Jan. 2019             399,461                                    52,738
# 1  Feb. 2019             384,967                                    53,365
# 2  Mar. 2019             447,155                                    53,145
# 3  Apr. 2019             442,921                                    54,225
# 4     19-May             475,897                                    55,641
#
#   Electronics and appliance stores Clothing stores Hobby, toy, and game stores
# 0                            7,162          11,955                       1,131
# 1                            6,562          12,514                       1,088
# 2                            7,192          16,212                       1,265
# 3                            6,489          15,820                       1,159
# 4                            7,112          16,829                       1,235

# %%
retail_food_20_file = "Resources/retail_food_20.csv"
retail_food_20_df = pd.read_csv(retail_food_20_file)
retail_food_20_df.head(20)
# Out:
#    Kind of Business Retail and food services sales, total  \
# 0         Jan. 2020                               480,301
# 1         Feb. 2020                               478,467
# 2         Mar. 2020                               478,267
# 3         Apr. 2020                               407,227
# 4            20-May                               504,607
# 5         Jun. 2020                               532,678
# 6         Jul. 2020                               549,416
# 7         Aug. 2020                               545,307
# 8         Sep. 2020                               530,987
# 9         Oct. 2020                               553,114
# 10        Nov. 2020                               543,273
# 11        Dec. 2020                               611,429
#
#    Retail sales and food services excl motor vehicle and parts  \
# 0                                             386,934
# 1                                             380,639
# ...

# %%
rename_retail_food_20 = retail_food_20_df.rename(columns={"Kind of Business":"Date"})
rename_retail_food_20.head()
# Out:
#         Date Retail and food services sales, total  \
# 0  Jan. 2020                               480,301
# 1  Feb. 2020                               478,467
# 2  Mar. 2020                               478,267
# 3  Apr. 2020                               407,227
# 4     20-May                               504,607
#
#   Retail sales and food services excl motor vehicle and parts  \
# 0                                            386,934
# 1                                            380,639
# 2                                            395,880
# 3                                            337,693
# 4                                            397,245
#
#   Retail sales and food services excl gasoline stations  \
# 0                                            440,605
# 1                                            441,504
# 2                                            444,006
# 3                                            380,417
# ...

# %%
reduced_retail_20_df = rename_retail_food_20[["Date", "Retail sales, total", "Electronic shopping and mail order houses", "Electronics and appliance stores", "Clothing stores", "Hobby, toy, and game stores"]]
reduced_retail_20_df.head()
# Out:
#         Date Retail sales, total Electronic shopping and mail order houses  \
# 0  Jan. 2020             418,734                                    57,822
# 1  Feb. 2020             415,511                                    58,027
# 2  Mar. 2020             430,527                                    61,256
# 3  Apr. 2020             377,210                                    70,809
# 4     20-May             462,286                                    75,424
#
#   Electronics and appliance stores Clothing stores Hobby, toy, and game stores
# 0                            7,079          12,287                       1,174
# 1                            6,687          13,439                       1,200
# 2                            5,816           7,584                         862
# 3                            3,040           1,736                         360
# 4                            3,952           5,504                       1,120

# %%
retail_food_21_file = "Resources/retail_food_21.csv"
retail_food_21_df = pd.read_csv(retail_food_21_file)
retail_food_21_df.head(20)
# Out:
#    Kind of Business Retail and food services sales, total  \
# 0         Jan. 2021                               517,119
# 1         Feb. 2021                               490,646
# 2         Mar. 2021                               633,078
# 3         Apr. 2021                               625,527
# 4          May.2021                               643,099
# 5         Jun. 2021                               635,437
# 6         Jul. 2021                               634,486
# 7         Aug. 2021                               631,415
# 8         Sep. 2021                               607,540
# 9         Oct. 2021                               634,076
# 10     Nov. 2021(p)                               649,933
#
#    Retail sales and food services excl motor vehicle and parts  \
# 0                                             412,864
# 1                                             387,850
# 2                                             486,171
# ...

# %%
rename_retail_food_21 = retail_food_21_df.rename(columns={"Kind of Business":"Date"})
rename_retail_food_21.head()
# Out:
#         Date Retail and food services sales, total  \
# 0  Jan. 2021                               517,119
# 1  Feb. 2021                               490,646
# 2  Mar. 2021                               633,078
# 3  Apr. 2021                               625,527
# 4   May.2021                               643,099
#
#   Retail sales and food services excl motor vehicle and parts  \
# 0                                            412,864
# 1                                            387,850
# 2                                            486,171
# 3                                            481,396
# 4                                            500,389
#
#   Retail sales and food services excl gasoline stations  \
# 0                                            479,905
# 1                                            454,351
# 2                                            586,718
# 3                                            578,253
# ...

# %%
reduced_retail_21_df = rename_retail_food_21[["Date", "Retail sales, total", "Electronic shopping and mail order houses", "Electronics and appliance stores", "Clothing stores", "Hobby, toy, and game stores"]]
reduced_retail_21_df.head()
# Out:
#         Date Retail sales, total Electronic shopping and mail order houses  \
# 0  Jan. 2021             464,362                                    78,993
# 1  Feb. 2021             440,019                                    75,939
# 2  Mar. 2021             567,933                                    80,201
# 3  Apr. 2021             558,181                                    80,048
# 4   May.2021             570,641                                    79,142
#
#   Electronics and appliance stores Clothing stores Hobby, toy, and game stores
# 0                            7,066          10,568                       1,646
# 1                            6,203          10,654                       1,445
# 2                            7,980          16,275                       1,980
# 3                            7,306          16,033                       1,777
# 4                            7,594          17,598                       1,768
